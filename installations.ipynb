# %%
#Install and freeze required dependencies for ease of access
# %pip install pandas
# %pip install torch
# %pip install datasets
# %pip install transformers
# %pip install openai
# %pip install subprocess
# %pip install sys
# General Libraries
# %pip install wandb                  # For experiment tracking and logging
# %pip install backoff                # For retrying operations with exponential backoff
# %pip install colorful               # For adding colors to text in console outputs
# Metrics and Scoring
# %pip install bert_score  # For evaluating text with BERTScore
# %pip install sklearn.metrics  # Scikit-learn metrics for ML evaluation
# SentencePiece
# %pip install sentencepiece
# %pip install gymnasium
# %pip freeze > requirements.txt
